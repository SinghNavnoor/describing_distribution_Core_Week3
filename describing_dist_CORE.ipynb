# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Data/data.csv')

df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
df.columns
# Out:
# Index(['State', 'Lat', 'Lng', 'Area', 'Children', 'Age', 'Income', 'Marital',
#        'Gender', 'ReAdmis', 'VitD_levels', 'Doc_visits', 'Full_meals_eaten',
#        'vitD_supp', 'Soft_drink', 'Initial_admin', 'HighBlood', 'Stroke',
#        'Complication_risk', 'Overweight', 'Arthritis', 'Diabetes',
#        'Hyperlipidemia', 'BackPain', 'Anxiety', 'Allergic_rhinitis',
#        'Reflux_esophagitis', 'Asthma', 'Services', 'Initial_days',
#        'TotalCharge', 'Additional_charges'],
#       dtype='object')

# %% [markdown]
# ## Exploring VitD_Levels

# %%
V_col = 'VitD_levels'
feature = df[V_col]
V_mean = feature.mean()
V_median = feature.median()
V_std = feature.std()
V_plus_one_std = V_mean + V_std
V_minus_one_std = V_mean - V_std

# %%
fig,ax = plt.subplots(figsize=(7,6))
sns.histplot(feature, ax = ax, stat='probability');
ax.axvline(V_mean, color = 'red', label = 'Mean');
ax.axvline(V_median, ls = '--', color = 'green', label = 'Median');
ax.axvline(V_plus_one_std, color = 'black', label =f'+1 std = {V_plus_one_std:,.2f}')
ax.axvline(V_minus_one_std, color = 'black', label =f'-1 std = {V_minus_one_std:,.2f}')
ax.axvspan(V_plus_one_std, V_minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{V_col}')
ax.legend();

# %% [markdown]
# #### This is a continuous value. Vitamin D levels can be described in infinite values.
# #### This feature does not have a Skew. It is very normally distributed.
# #### This feature is also Leptokurtic. We can see that values are concentrated in the center.

# %% [markdown]
# ## Exploring Doc_visits

# %%
d_col = 'Doc_visits'
d_feature = df[d_col]
d_mean = d_feature.mean()
d_median = d_feature.median()
d_std = d_feature.std()
d_plus_one_std = d_mean + d_std
d_minus_one_std = d_mean - d_std

# %%
fig,ax = plt.subplots(figsize=(7,6))
sns.histplot(d_feature, ax = ax, stat='probability');
ax.axvline(d_mean, color = 'red', label = 'Mean');
ax.axvline(d_median, ls = '--', color = 'green', label = 'Median');
ax.axvline(d_plus_one_std, color = 'black', label =f'+1 std = {d_plus_one_std:,.2f}')
ax.axvline(d_minus_one_std, color = 'black', label =f'-1 std = {d_minus_one_std:,.2f}')
ax.axvspan(d_plus_one_std, d_minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{d_col}')
ax.legend();

# %% [markdown]
# #### It is a Discrete feature. The reason being that there are only a set number of times one can visit the doctor in a given time frame.
#
# #### It is not skewed. It is normally distributed.
#
# #### This is a Leptokurtic distribution. Looks like that most individuals have have anywhere between 4 - 6 doctors visits.

# %% [markdown]
# ## Exploring TotalCharges

# %%
t_col = 'TotalCharge'
t_feature = df[t_col]
t_mean = t_feature.mean()
t_median = t_feature.median()
t_std = t_feature.std()
t_plus_one_std = t_mean + t_std
t_minus_one_std = t_mean - t_std

# %%
fig,ax = plt.subplots(figsize=(7,6))
sns.histplot(t_feature, ax = ax, stat='probability');
ax.axvline(t_mean, color = 'red', label = 'Mean');
ax.axvline(t_median, ls = '--', color = 'green', label = 'Median');
ax.axvline(t_plus_one_std, color = 'black', label =f'+1 std = {t_plus_one_std:,.2f}')
ax.axvline(t_minus_one_std, color = 'black', label =f'-1 std = {t_minus_one_std:,.2f}')
ax.axvspan(t_plus_one_std, t_minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{t_col}')
ax.legend();

# %% [markdown]
# #### It is a continuous distribution. The reason being that there is no limit to how much a person can be charged for.
# #### Its a slightly right skewed distribution.
# #### It is Mesokurtic. The reason being that the values are more spread out.
